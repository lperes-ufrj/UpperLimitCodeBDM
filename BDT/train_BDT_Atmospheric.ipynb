# %%
import ROOT

# in order to start TMVA
ROOT.TMVA.Tools.Instance()

# %%
# open file
path = '/media/leoperes/Acer/Users/le0_p/ntuples_grid_newVertex/00a_newVertex/'
stree = ROOT.TFile.Open(path+'atm_hA_BR.root')

# get trees 
tree_s = stree.Get("ana/Atm")
tree_b = stree.Get("ana/Atm")

fout = ROOT.TFile("BDT_Atm.root","RECREATE")

# %%
# define factory with options
factory = ROOT.TMVA.Factory("TMVAClassification", fout, #TMVA::Factory( "<JobName>", outputFile, "<options>" );
                            ":".join([    "!V", # Verbose flag, default=False
                                          "!Silent", # Batch mode: boolean silent flag inhibiting any output from TMVA after the creation of the factory class object (default: False)
                                          "Color", # Flag for coloured screen output (default: True, if in batch mode: False)
                                          "DrawProgressBar", # Draw progress bar to display training, testing and evaluation schedule (default: True)
                                          "Transformations=I;D;P;U;G,D", # List of transformations to test; formatting example: Transformations=I;D;P;U;G,D, for identity, decorrelation, PCA, Uniform and Gaussianisation followed by decorrelation transformations
                                          "AnalysisType=Classification"] # Set the analysis type (Classification, Regression, Multiclass, Auto) (default: Auto)
                                     ))

# %%
dataloader = ROOT.TMVA.DataLoader("dataset")

dataloader.AddSpectator("event", "I")
# add discriminating variables for training
dataloader.AddVariable("LongestTrack","F") # Longest Track in the event [cm]
#dataloader.AddVariable("log(HighestTrackSummedADC)","F") # Highest Track ADC deposition in the events [ADC Units]
dataloader.AddVariable("PIDALongestTrack", "F") # PIDA of the longest track
dataloader.AddVariable("nTracks", "I") # number of tracks in the event
dataloader.AddVariable("nShowers", "I") # number of showers in the event
#dataloader.AddVariable("TotalMomentumP", "F") # total momentum magnitude of the event with only tracks info
dataloader.AddVariable("NHits", "I") # number of 3d space points reco
#dataloader.AddVariable("NPrimaryDaughters", "I") # nShowers+nTracks in the event (irrelevant, it can be take off)
dataloader.AddVariable("log(HighestShowerSummedADC)", "F") # Highest Shower ADC deposition in the events [ADC Units]
#dataloader.AddVariable("PrimaryPDGReco", "I") # Pandora returns for nue or numu
dataloader.AddVariable("LargeShowerOpenAngle", "F") # Large shower open Angle [rad]
dataloader.AddVariable("LongestShower", "F") # Longest Shower in the event [cm]
#dataloader.AddVariable("CosThetaDetTotalMom", "F") # Total momentum Cossine Theta detector coordinates.
#dataloader.AddVariable("CosPhiDetTotalMom", "F") # Total momentum Cossine Phi detector coordinates.
dataloader.AddVariable("FracTotalChargeLongTrack", "F") # How much of the total charge of the event the longest track carries
dataloader.AddVariable("AvarageTrackLength", "F") # Avarage track length in the event [cm]
dataloader.AddVariable("CVN_NCScore", "F") # CVN score for NC
dataloader.AddVariable("EventRecoEnergy_Charge", "F") # Event Energy given the charge deposition in the event.

# %%
# define signal and background trees
dataloader.AddSignalTree(tree_s)
dataloader.AddBackgroundTree(tree_b)
# Out:
# DataSetInfo              : [dataset] : Added class "Signal"
#                          : Add Tree Atm of type Signal with 3019964 events
# DataSetInfo              : [dataset] : Added class "Background"
#                          : Add Tree Atm of type Background with 3019964 events

# %%
# define additional cuts 
sigCut = ROOT.TCut("CCNC == 1 && event < 2300000")
bgCut = ROOT.TCut("CCNC == 0 && event < 2300000")

# %%
# set options for trainings
dataloader.PrepareTrainingAndTestTree(sigCut, 
                                   bgCut, 
                                   ":".join(["nTrain_Signal=638496",
                                             "nTrain_Background=1967354",
                                             "SplitMode=Random",
                                             "NormMode=None",
                                             "!V"
                                             ]))

# %%
method = factory.BookMethod(dataloader, ROOT.TMVA.Types.kBDT, "BDTAtmCCNC_NoNorm",
                            ":".join([ "!H",
                                       "!V",
                                       "NTrees=800",
                                       "MinNodeSize=5%",
                                       "MaxDepth=3",
                                       "BoostType=AdaBoost",
                                       "AdaBoostBeta=0.5",
                                       "SeparationType=GiniIndex",
                                       "nCuts=20",
                                       "PruneMethod=NoPruning",
                                       "DoBoostMonitor=True"
                                       ]))
# Out:
# Factory                  : Booking method: BDTAtmCCNC_NoNorm
#                          :
#                          : Rebuilding Dataset dataset
#                          : Building event vectors for type 2 Signal
#                          : Dataset[dataset] :  create input formulas for tree Atm
#                          : Building event vectors for type 2 Background
#                          : Dataset[dataset] :  create input formulas for tree Atm
# DataSetFactory           : [dataset] : Number of events in input trees
#                          : Dataset[dataset] :     Signal     requirement: "CCNC == 1 && event < 2300000"
#                          : Dataset[dataset] :     Signal          -- number of events passed: 685605  / sum of weights: 685605
#                          : Dataset[dataset] :     Signal          -- efficiency             : 0.227024
#                          : Dataset[dataset] :     Background requirement: "CCNC == 0 && event < 2300000"
#                          : Dataset[dataset] :     Background      -- number of events passed: 2096424  / sum of weights: 2.09642e+06
#                          : Dataset[dataset] :     Background      -- efficiency             : 0.694188
#                          : Dataset[dataset] :  you have opted for interpreting the requested number of training/testing events
#                          :  to be the number of events AFTER your preselection cuts
#                          :
#                          : Dataset[dataset] :  you have opted for interpreting the requested number of training/testing events
#                          :  to be the number of events AFTER your preselection cuts
#                          :
#                          : Dataset[dataset] : No weight renormalisation applied: use original global and event weights
# DataSetInfo              : Correlation matrix (Signal):
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                              LongestTrack log_HighestTrackSummedADC_ PIDALongestTrack nTracks nShowers   NHits log_HighestShowerSummedADC_ LargeShowerOpenAngle LongestShower FracTotalChargeLongTrack AvarageTrackLength CVN_NCScore EventRecoEnergy_Charge
#                          :                LongestTrack:       +1.000                     +0.034           -0.012  +0.177   +0.078  +0.216                      +0.049               +0.060        +0.066                   -0.048             +0.740      +0.017                 +0.168
#                          :  log_HighestTrackSummedADC_:       +0.034                     +1.000           +0.348  +0.264   -0.220  +0.018                      -0.361               -0.197        -0.188                   +0.349             +0.150      -0.055                 +0.019
#                          :            PIDALongestTrack:       -0.012                     +0.348           +1.000  +0.013   -0.169  -0.065                      -0.235               -0.159        -0.138                   +0.229             -0.027      -0.018                 -0.044
#                          :                     nTracks:       +0.177                     +0.264           +0.013  +1.000   +0.327  +0.646                      +0.212               +0.255        +0.307                   -0.367             +0.212      +0.117                 +0.539
#                          :                    nShowers:       +0.078                     -0.220           -0.169  +0.327   +1.000  +0.557                      +0.796               +0.736        +0.679                   -0.505             +0.103      +0.172                 +0.482
#                          :                       NHits:       +0.216                     +0.018           -0.065  +0.646   +0.557  +1.000                      +0.456               +0.427        +0.657                   -0.340             +0.288      +0.081                 +0.927
#                          : log_HighestShowerSummedADC_:       +0.049                     -0.361           -0.235  +0.212   +0.796  +0.456                      +1.000               +0.723        +0.738                   -0.619             +0.073      +0.224                 +0.386
#                          :        LargeShowerOpenAngle:       +0.060                     -0.197           -0.159  +0.255   +0.736  +0.427                      +0.723               +1.000        +0.500                   -0.452             +0.088      +0.167                 +0.362
#                          :               LongestShower:       +0.066                     -0.188           -0.138  +0.307   +0.679  +0.657                      +0.738               +0.500        +1.000                   -0.451             +0.111      +0.119                 +0.592
#                          :    FracTotalChargeLongTrack:       -0.048                     +0.349           +0.229  -0.367   -0.505  -0.340                      -0.619               -0.452        -0.451                   +1.000             -0.027      -0.392                 -0.266
#                          :          AvarageTrackLength:       +0.740                     +0.150           -0.027  +0.212   +0.103  +0.288                      +0.073               +0.088        +0.111                   -0.027             +1.000      +0.083                 +0.222
#                          :                 CVN_NCScore:       +0.017                     -0.055           -0.018  +0.117   +0.172  +0.081                      +0.224               +0.167        +0.119                   -0.392             +0.083      +1.000                 +0.051
#                          :      EventRecoEnergy_Charge:       +0.168                     +0.019           -0.044  +0.539   +0.482  +0.927                      +0.386               +0.362        +0.592                   -0.266             +0.222      +0.051                 +1.000
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# DataSetInfo              : Correlation matrix (Background):
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                              LongestTrack log_HighestTrackSummedADC_ PIDALongestTrack nTracks nShowers   NHits log_HighestShowerSummedADC_ LargeShowerOpenAngle LongestShower FracTotalChargeLongTrack AvarageTrackLength CVN_NCScore EventRecoEnergy_Charge
#                          :                LongestTrack:       +1.000                     +0.086           -0.013  +0.189   +0.016  +0.215                      -0.048               +0.014        -0.023                   +0.028             +0.595      -0.044                 +0.140
#                          :  log_HighestTrackSummedADC_:       +0.086                     +1.000           +0.355  +0.363   -0.164  +0.072                      -0.353               -0.124        -0.241                   +0.336             +0.238      +0.044                 +0.044
#                          :            PIDALongestTrack:       -0.013                     +0.355           +1.000  +0.117   +0.011  +0.039                      -0.005               +0.009        +0.013                   +0.038             -0.037      +0.039                 +0.043
#                          :                     nTracks:       +0.189                     +0.363           +0.117  +1.000   +0.221  +0.602                      -0.010               +0.175        +0.067                   -0.228             +0.083      +0.080                 +0.460
#                          :                    nShowers:       +0.016                     -0.164           +0.011  +0.221   +1.000  +0.501                      +0.724               +0.705        +0.590                   -0.376             -0.104      +0.083                 +0.466
#                          :                       NHits:       +0.215                     +0.072           +0.039  +0.602   +0.501  +1.000                      +0.339               +0.373        +0.492                   -0.244             +0.188      +0.014                 +0.884
#                          : log_HighestShowerSummedADC_:       -0.048                     -0.353           -0.005  -0.010   +0.724  +0.339                      +1.000               +0.608        +0.764                   -0.501             -0.206      -0.016                 +0.328
#                          :        LargeShowerOpenAngle:       +0.014                     -0.124           +0.009  +0.175   +0.705  +0.373                      +0.608               +1.000        +0.370                   -0.300             -0.078      +0.071                 +0.344
#                          :               LongestShower:       -0.023                     -0.241           +0.013  +0.067   +0.590  +0.492                      +0.764               +0.370        +1.000                   -0.405             -0.141      -0.019                 +0.474
#                          :    FracTotalChargeLongTrack:       +0.028                     +0.336           +0.038  -0.228   -0.376  -0.244                      -0.501               -0.300        -0.405                   +1.000             +0.318      -0.019                 -0.205
#                          :          AvarageTrackLength:       +0.595                     +0.238           -0.037  +0.083   -0.104  +0.188                      -0.206               -0.078        -0.141                   +0.318             +1.000      -0.133                 +0.099
#                          :                 CVN_NCScore:       -0.044                     +0.044           +0.039  +0.080   +0.083  +0.014                      -0.016               +0.071        -0.019                   -0.019             -0.133      +1.000                 +0.073
#                          :      EventRecoEnergy_Charge:       +0.140                     +0.044           +0.043  +0.460   +0.466  +0.884                      +0.328               +0.344        +0.474                   -0.205             +0.099      +0.073                 +1.000
#                          : ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# DataSetFactory           : [dataset] :
#                          :

# %%
# self-explaining
factory.TrainAllMethods()
factory.TestAllMethods()
factory.EvaluateAllMethods()
# Out:
# Factory                  : Train all methods
# Factory                  : [dataset] : Create Transformation "I" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'LongestTrack' <---> Output : variable 'LongestTrack'
#                          : Input : variable 'log(HighestTrackSummedADC)' <---> Output : variable 'log(HighestTrackSummedADC)'
#                          : Input : variable 'PIDALongestTrack' <---> Output : variable 'PIDALongestTrack'
#                          : Input : variable 'nTracks' <---> Output : variable 'nTracks'
#                          : Input : variable 'nShowers' <---> Output : variable 'nShowers'
#                          : Input : variable 'NHits' <---> Output : variable 'NHits'
#                          : Input : variable 'log(HighestShowerSummedADC)' <---> Output : variable 'log(HighestShowerSummedADC)'
#                          : Input : variable 'LargeShowerOpenAngle' <---> Output : variable 'LargeShowerOpenAngle'
#                          : Input : variable 'LongestShower' <---> Output : variable 'LongestShower'
#                          : Input : variable 'FracTotalChargeLongTrack' <---> Output : variable 'FracTotalChargeLongTrack'
#                          : Input : variable 'AvarageTrackLength' <---> Output : variable 'AvarageTrackLength'
#                          : Input : variable 'CVN_NCScore' <---> Output : variable 'CVN_NCScore'
#                          : Input : variable 'EventRecoEnergy_Charge' <---> Output : variable 'EventRecoEnergy_Charge'
# Factory                  : [dataset] : Create Transformation "D" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'LongestTrack' <---> Output : variable 'LongestTrack'
#                          : Input : variable 'log(HighestTrackSummedADC)' <---> Output : variable 'log(HighestTrackSummedADC)'
#                          : Input : variable 'PIDALongestTrack' <---> Output : variable 'PIDALongestTrack'
#                          : Input : variable 'nTracks' <---> Output : variable 'nTracks'
#                          : Input : variable 'nShowers' <---> Output : variable 'nShowers'
#                          : Input : variable 'NHits' <---> Output : variable 'NHits'
#                          : Input : variable 'log(HighestShowerSummedADC)' <---> Output : variable 'log(HighestShowerSummedADC)'
#                          : Input : variable 'LargeShowerOpenAngle' <---> Output : variable 'LargeShowerOpenAngle'
#                          : Input : variable 'LongestShower' <---> Output : variable 'LongestShower'
#                          : Input : variable 'FracTotalChargeLongTrack' <---> Output : variable 'FracTotalChargeLongTrack'
#                          : Input : variable 'AvarageTrackLength' <---> Output : variable 'AvarageTrackLength'
#                          : Input : variable 'CVN_NCScore' <---> Output : variable 'CVN_NCScore'
#                          : Input : variable 'EventRecoEnergy_Charge' <---> Output : variable 'EventRecoEnergy_Charge'
# Factory                  : [dataset] : Create Transformation "P" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'LongestTrack' <---> Output : variable 'LongestTrack'
#                          : Input : variable 'log(HighestTrackSummedADC)' <---> Output : variable 'log(HighestTrackSummedADC)'
#                          : Input : variable 'PIDALongestTrack' <---> Output : variable 'PIDALongestTrack'
#                          : Input : variable 'nTracks' <---> Output : variable 'nTracks'
#                          : Input : variable 'nShowers' <---> Output : variable 'nShowers'
#                          : Input : variable 'NHits' <---> Output : variable 'NHits'
#                          : Input : variable 'log(HighestShowerSummedADC)' <---> Output : variable 'log(HighestShowerSummedADC)'
#                          : Input : variable 'LargeShowerOpenAngle' <---> Output : variable 'LargeShowerOpenAngle'
#                          : Input : variable 'LongestShower' <---> Output : variable 'LongestShower'
#                          : Input : variable 'FracTotalChargeLongTrack' <---> Output : variable 'FracTotalChargeLongTrack'
#                          : Input : variable 'AvarageTrackLength' <---> Output : variable 'AvarageTrackLength'
#                          : Input : variable 'CVN_NCScore' <---> Output : variable 'CVN_NCScore'
#                          : Input : variable 'EventRecoEnergy_Charge' <---> Output : variable 'EventRecoEnergy_Charge'
# Factory                  : [dataset] : Create Transformation "U" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'LongestTrack' <---> Output : variable 'LongestTrack'
#                          : Input : variable 'log(HighestTrackSummedADC)' <---> Output : variable 'log(HighestTrackSummedADC)'
#                          : Input : variable 'PIDALongestTrack' <---> Output : variable 'PIDALongestTrack'
#                          : Input : variable 'nTracks' <---> Output : variable 'nTracks'
#                          : Input : variable 'nShowers' <---> Output : variable 'nShowers'
#                          : Input : variable 'NHits' <---> Output : variable 'NHits'
#                          : Input : variable 'log(HighestShowerSummedADC)' <---> Output : variable 'log(HighestShowerSummedADC)'
#                          : Input : variable 'LargeShowerOpenAngle' <---> Output : variable 'LargeShowerOpenAngle'
#                          : Input : variable 'LongestShower' <---> Output : variable 'LongestShower'
#                          : Input : variable 'FracTotalChargeLongTrack' <---> Output : variable 'FracTotalChargeLongTrack'
#                          : Input : variable 'AvarageTrackLength' <---> Output : variable 'AvarageTrackLength'
#                          : Input : variable 'CVN_NCScore' <---> Output : variable 'CVN_NCScore'
#                          : Input : variable 'EventRecoEnergy_Charge' <---> Output : variable 'EventRecoEnergy_Charge'
# Factory                  : [dataset] : Create Transformation "G" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'LongestTrack' <---> Output : variable 'LongestTrack'
#                          : Input : variable 'log(HighestTrackSummedADC)' <---> Output : variable 'log(HighestTrackSummedADC)'
#                          : Input : variable 'PIDALongestTrack' <---> Output : variable 'PIDALongestTrack'
#                          : Input : variable 'nTracks' <---> Output : variable 'nTracks'
#                          : Input : variable 'nShowers' <---> Output : variable 'nShowers'
#                          : Input : variable 'NHits' <---> Output : variable 'NHits'
#                          : Input : variable 'log(HighestShowerSummedADC)' <---> Output : variable 'log(HighestShowerSummedADC)'
#                          : Input : variable 'LargeShowerOpenAngle' <---> Output : variable 'LargeShowerOpenAngle'
#                          : Input : variable 'LongestShower' <---> Output : variable 'LongestShower'
#                          : Input : variable 'FracTotalChargeLongTrack' <---> Output : variable 'FracTotalChargeLongTrack'
#                          : Input : variable 'AvarageTrackLength' <---> Output : variable 'AvarageTrackLength'
#                          : Input : variable 'CVN_NCScore' <---> Output : variable 'CVN_NCScore'
#                          : Input : variable 'EventRecoEnergy_Charge' <---> Output : variable 'EventRecoEnergy_Charge'
# Factory                  : [dataset] : Create Transformation "D" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'LongestTrack' <---> Output : variable 'LongestTrack'
#                          : Input : variable 'log(HighestTrackSummedADC)' <---> Output : variable 'log(HighestTrackSummedADC)'
#                          : Input : variable 'PIDALongestTrack' <---> Output : variable 'PIDALongestTrack'
#                          : Input : variable 'nTracks' <---> Output : variable 'nTracks'
#                          : Input : variable 'nShowers' <---> Output : variable 'nShowers'
#                          : Input : variable 'NHits' <---> Output : variable 'NHits'
#                          : Input : variable 'log(HighestShowerSummedADC)' <---> Output : variable 'log(HighestShowerSummedADC)'
#                          : Input : variable 'LargeShowerOpenAngle' <---> Output : variable 'LargeShowerOpenAngle'
#                          : Input : variable 'LongestShower' <---> Output : variable 'LongestShower'
#                          : Input : variable 'FracTotalChargeLongTrack' <---> Output : variable 'FracTotalChargeLongTrack'
#                          : Input : variable 'AvarageTrackLength' <---> Output : variable 'AvarageTrackLength'
#                          : Input : variable 'CVN_NCScore' <---> Output : variable 'CVN_NCScore'
#                          : Input : variable 'EventRecoEnergy_Charge' <---> Output : variable 'EventRecoEnergy_Charge'
# TFHandler_Factory        :                    Variable                           Mean                           RMS                   [        Min                           Max ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                LongestTrack:                       85.190                       469.27   [                   1.0000e-10                   2.2051e+05 ]
#                          :  log(HighestTrackSummedADC):                       6.0897                       10.849   [                      -23.026                       17.134 ]
#                          :            PIDALongestTrack:                       13.087                       13.658   [                       0.0000                       60.000 ]
#                          :                     nTracks:                       1.9853                       1.8199   [                       0.0000                       57.000 ]
#                          :                    nShowers:                      0.89700                       1.2021   [                       0.0000                       18.000 ]
#                          :                       NHits:                       1413.8                       2292.2   [                       14.000                       62110. ]
#                          : log(HighestShowerSummedADC):                       6.1696                       6.0547   [                       0.0000                       17.860 ]
#                          :        LargeShowerOpenAngle:                      0.12233                      0.18589   [                       0.0000                       1.5708 ]
#                          :               LongestShower:                       36.971                       54.015   [                       0.0000                       1394.2 ]
#                          :    FracTotalChargeLongTrack:                      0.21287                      0.26720   [                   1.9000e-18                       1.0000 ]
#                          :          AvarageTrackLength:                       47.236                       95.780   [                       0.0000                       16402. ]
#                          :                 CVN_NCScore:                      0.46595                      0.49221   [                      -1.0000                       1.0000 ]
#                          :      EventRecoEnergy_Charge:                       1.3025                       3.0139   [                       0.0000                       89.121 ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          : Preparing the Decorrelation transformation...
# TFHandler_Factory        :                    Variable                           Mean                           RMS                   [        Min                           Max ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                LongestTrack:                     0.028470                       1.0000   [                      -3.3767                       501.60 ]
#                          :  log(HighestTrackSummedADC):                      0.41991                       1.0000   [                      -35.490                       25.862 ]
#                          :            PIDALongestTrack:                      0.94791                       1.0000   [                      -6.1028                       20.017 ]
#                          :                     nTracks:                       1.1296                       1.0000   [                      -59.401                       42.866 ]
#                          :                    nShowers:                     -0.12149                       1.0000   [                      -12.761                       19.909 ]
#                          :                       NHits:                      0.60523                       1.0000   [                      -4.5625                       27.279 ]
#                          : log(HighestShowerSummedADC):                       1.0832                       1.0000   [                      -24.798                       18.979 ]
#                          :        LargeShowerOpenAngle:                     -0.14960                       1.0000   [                      -8.9501                       13.673 ]
#                          :               LongestShower:                      0.46785                       1.0000   [                      -17.922                       32.166 ]
#                          :    FracTotalChargeLongTrack:                       1.8723                       1.0000   [                      -32.060                       39.642 ]
#                          :          AvarageTrackLength:                      0.47839                       1.0000   [                      -200.59                       197.18 ]
#                          :                 CVN_NCScore:                      0.95009                       1.0000   [                      -5.2133                       17.351 ]
#                          :      EventRecoEnergy_Charge:                     -0.14487                       1.0000   [                      -14.702                       50.151 ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          : Preparing the Principle Component (PCA) transformation...
# TFHandler_Factory        :                    Variable                           Mean                           RMS                   [        Min                           Max ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                LongestTrack:                   6.1926e-08                       2294.9   [                      -1402.4                       61165. ]
#                          :  log(HighestTrackSummedADC):                  -9.9565e-09                       460.96   [                  -2.1771e+05                       2156.4 ]
#                          :            PIDALongestTrack:                   1.0089e-09                       75.929   [                      -19803.                       13927. ]
#                          :                     nTracks:                  -2.4961e-10                       44.261   [                      -916.17                       2798.2 ]
#                          :                    nShowers:                  -8.1493e-12                       14.509   [                      -51.563                       106.18 ]
#                          :                       NHits:                  -1.2267e-11                       8.8507   [                      -388.59                       280.75 ]
#                          : log(HighestShowerSummedADC):                   5.6702e-11                       3.7542   [                      -96.747                       54.330 ]
#                          :        LargeShowerOpenAngle:                  -2.7812e-12                       1.4430   [                      -65.473                       35.538 ]
#                          :               LongestShower:                  -4.1746e-11                       1.1548   [                      -54.221                       63.703 ]
#                          :    FracTotalChargeLongTrack:                   1.6225e-11                      0.73876   [                      -14.835                       9.2863 ]
#                          :          AvarageTrackLength:                   2.7685e-13                      0.47960   [                      -6.8345                       3.2524 ]
#                          :                 CVN_NCScore:                  -1.2829e-12                      0.19611   [                      -6.5329                       5.9509 ]
#                          :      EventRecoEnergy_Charge:                  -1.6128e-12                      0.12072   [                      -1.7156                       1.1834 ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          : Preparing the Gaussian transformation...
# TFHandler_Factory        :                    Variable                           Mean                           RMS                   [        Min                           Max ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                LongestTrack:                      0.44669                      0.30162   [                     0.055023                       1.0000 ]
#                          :  log(HighestTrackSummedADC):                      0.44021                      0.31572   [                   0.00056818                       1.0000 ]
#                          :            PIDALongestTrack:                      0.46392                      0.33150   [                   0.00060403                       1.0000 ]
#                          :                     nTracks:                      0.45864                      0.26655   [                   1.6060e-05                       1.0000 ]
#                          :                    nShowers:                      0.55992                      0.26505   [                      0.29536                       1.0000 ]
#                          :                       NHits:                      0.50023                      0.28742   [                   0.00012303                       1.0000 ]
#                          : log(HighestShowerSummedADC):                      0.26067                      0.32482   [                   0.00096063                       1.0000 ]
#                          :        LargeShowerOpenAngle:                      0.26098                      0.32455   [                    0.0016232                       1.0000 ]
#                          :               LongestShower:                      0.26110                      0.32447   [                    0.0018655                       1.0000 ]
#                          :    FracTotalChargeLongTrack:                      0.50088                      0.28852   [                     0.061117                      0.99417 ]
#                          :          AvarageTrackLength:                      0.44015                      0.31574   [                   1.0000e-09                       1.0000 ]
#                          :                 CVN_NCScore:                      0.48191                      0.29844   [                   0.00051895                       1.0000 ]
#                          :      EventRecoEnergy_Charge:                      0.50047                      0.28851   [                   0.00050044                       1.0000 ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          : Preparing the Gaussian transformation...
#                          : Preparing the Decorrelation transformation...
# TFHandler_Factory        :                    Variable                           Mean                           RMS                   [        Min                           Max ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                LongestTrack:                     -0.32431                       1.0000   [                      -5.0406                       7.8614 ]
#                          :  log(HighestTrackSummedADC):                     -0.30923                       1.0000   [                      -6.2622                       7.1400 ]
#                          :            PIDALongestTrack:                     0.061413                       1.0000   [                      -2.2985                       4.2585 ]
#                          :                     nTracks:                     -0.28682                       1.0000   [                      -3.2351                       5.7026 ]
#                          :                    nShowers:                       2.3841                       1.0000   [                      -2.5701                       13.732 ]
#                          :                       NHits:                      0.45325                       1.0000   [                      -6.5794                       10.793 ]
#                          : log(HighestShowerSummedADC):                      -1.0038                       1.0000   [                      -8.0386                       8.6982 ]
#                          :        LargeShowerOpenAngle:                      -1.2345                       1.0000   [                      -5.1502                       7.4114 ]
#                          :               LongestShower:                      -1.0197                       1.0000   [                      -8.4619                       10.951 ]
#                          :    FracTotalChargeLongTrack:                      0.13127                       1.0000   [                      -4.3098                       5.8804 ]
#                          :          AvarageTrackLength:                     -0.46299                       1.0000   [                      -8.5042                       6.4261 ]
#                          :                 CVN_NCScore:                     -0.18355                       1.0000   [                      -3.1656                       5.0955 ]
#                          :      EventRecoEnergy_Charge:                      0.70994                       1.0000   [                      -7.6294                       14.772 ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          : Ranking input variables (method unspecific)...
# IdTransformation         : Ranking result (top variable is best ranked)
#                          : ----------------------------------------------------
#                          : Rank : Variable                    : Separation
#                          : ----------------------------------------------------
#                          :    1 : CVN_NCScore                 : 4.978e-01
#                          :    2 : NHits                       : 1.615e-01
#                          :    3 : FracTotalChargeLongTrack    : 8.177e-02
#                          :    4 : PIDALongestTrack            : 6.905e-02
#                          :    5 : EventRecoEnergy_Charge      : 5.890e-02
#                          :    6 : AvarageTrackLength          : 5.087e-02
#                          :    7 : log(HighestShowerSummedADC) : 4.778e-02
#                          :    8 : LongestShower               : 4.554e-02
#                          :    9 : LongestTrack                : 4.426e-02
#                          :   10 : LargeShowerOpenAngle        : 3.990e-02
#                          :   11 : nShowers                    : 3.587e-02
#                          :   12 : nTracks                     : 3.293e-02
#                          :   13 : log(HighestTrackSummedADC)  : 2.659e-02
#                          : ----------------------------------------------------
# Factory                  : Train method: BDTAtmCCNC_NoNorm for Classification
#                          :
# BDTAtmCCNC_NoNorm        : #events: (reweighted) sig: 1.30292e+06 bkg: 1.30292e+06
#                          : #events: (unweighted) sig: 638496 bkg: 1967354
#                          : Training 800 Decision Trees ... patience please
#                          : Elapsed time for training with 2605850 events: 872 sec
# BDTAtmCCNC_NoNorm        : [dataset] : Evaluation of BDTAtmCCNC_NoNorm on training sample (2605850 events)
#                          : Elapsed time for evaluation of 2605850 events: 78.5 sec
#                          : Creating xml weight file: dataset/weights/TMVAClassification_BDTAtmCCNC_NoNorm.weights.xml
#                          : Creating standalone class: dataset/weights/TMVAClassification_BDTAtmCCNC_NoNorm.class.C
#                          : BDT_Atm.root:/dataset/Method_BDT/BDTAtmCCNC_NoNorm
# Factory                  : Training finished
#                          :
#                          : Ranking input variables (method specific)...
# BDTAtmCCNC_NoNorm        : Ranking result (top variable is best ranked)
#                          : -------------------------------------------------------------
#                          : Rank : Variable                    : Variable Importance
#                          : -------------------------------------------------------------
#                          :    1 : CVN_NCScore                 : 2.452e-01
#                          :    2 : NHits                       : 1.783e-01
#                          :    3 : FracTotalChargeLongTrack    : 8.753e-02
#                          :    4 : PIDALongestTrack            : 8.427e-02
#                          :    5 : EventRecoEnergy_Charge      : 7.653e-02
#                          :    6 : nTracks                     : 6.767e-02
#                          :    7 : log(HighestShowerSummedADC) : 6.602e-02
#                          :    8 : LargeShowerOpenAngle        : 5.504e-02
#                          :    9 : LongestShower               : 4.887e-02
#                          :   10 : log(HighestTrackSummedADC)  : 4.532e-02
#                          :   11 : nShowers                    : 4.524e-02
#                          :   12 : LongestTrack                : 0.000e+00
#                          :   13 : AvarageTrackLength          : 0.000e+00
#                          : -------------------------------------------------------------
# Factory                  : === Destroy and recreate all methods via weight files for testing ===
#                          :
#                          : Reading weight file: dataset/weights/TMVAClassification_BDTAtmCCNC_NoNorm.weights.xml
# Factory                  : Test all methods
# Factory                  : Test method: BDTAtmCCNC_NoNorm for Classification performance
#                          :
# BDTAtmCCNC_NoNorm        : [dataset] : Evaluation of BDTAtmCCNC_NoNorm on testing sample (176179 events)
#                          : Elapsed time for evaluation of 176179 events: 4.52 sec
# Factory                  : Evaluate all methods
# Factory                  : Evaluate classifier: BDTAtmCCNC_NoNorm
#                          :
# BDTAtmCCNC_NoNorm        : [dataset] : Loop over test events and fill histograms with classifier response...
#                          :
# TFHandler_BDTAtmCCNC_N...:                    Variable                           Mean                           RMS                   [        Min                           Max ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :                LongestTrack:                       84.227                       316.06   [                   1.0000e-10                       35163. ]
#                          :  log(HighestTrackSummedADC):                       6.1692                       10.757   [                      -23.026                       17.006 ]
#                          :            PIDALongestTrack:                       13.206                       13.714   [                       0.0000                       60.000 ]
#                          :                     nTracks:                       1.9814                       1.8142   [                       0.0000                       36.000 ]
#                          :                    nShowers:                      0.89447                       1.2023   [                       0.0000                       14.000 ]
#                          :                       NHits:                       1399.9                       2277.7   [                       18.000                       47652. ]
#                          : log(HighestShowerSummedADC):                       6.1238                       6.0500   [                       0.0000                       17.504 ]
#                          :        LargeShowerOpenAngle:                      0.12217                      0.18585   [                       0.0000                       1.5577 ]
#                          :               LongestShower:                       36.549                       53.429   [                       0.0000                       1190.2 ]
#                          :    FracTotalChargeLongTrack:                      0.21620                      0.26899   [                   2.9892e-18                       1.0000 ]
#                          :          AvarageTrackLength:                       46.932                       85.661   [                       0.0000                       5878.9 ]
#                          :                 CVN_NCScore:                      0.47025                      0.50035   [                      -1.0000                       1.0000 ]
#                          :      EventRecoEnergy_Charge:                       1.2863                       2.9745   [                       0.0000                       88.578 ]
#                          : ----------------------------------------------------------------------------------------------------------------------------------------------------------
#                          :
#                          : Evaluation results ranked by best signal efficiency and purity (area)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet       MVA
#                          : Name:         Method:          ROC-integ
#                          : dataset       BDTAtmCCNC_NoNorm: 0.924
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
#                          : Testing efficiency compared to training efficiency (overtraining check)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : DataSet              MVA              Signal efficiency: from test sample (from training sample)
#                          : Name:                Method:          @B=0.01             @B=0.10            @B=0.30
#                          : -------------------------------------------------------------------------------------------------------------------
#                          : dataset              BDTAtmCCNC_NoNorm: 0.439 (0.438)       0.756 (0.756)      0.931 (0.930)
#                          : -------------------------------------------------------------------------------------------------------------------
#                          :
# Dataset:dataset          : Created tree 'TestTree' with 176179 events
#                          :
# Dataset:dataset          : Created tree 'TrainTree' with 2605850 events
#                          :
# Factory                  : Thank you for using TMVA!
#                          : For citation information, please visit: http://tmva.sf.net/citeTMVA.html
# 0%, time left: unknown
# 6%, time left: 13 mins
# 12%, time left: 12 mins
# 18%, time left: 11 mins
# 25%, time left: 10 mins
# 31%, time left: 9 mins
# 37%, time left: 8 mins
# 43%, time left: 7 mins
# 50%, time left: 6 mins
# 56%, time left: 6 mins
# 62%, time left: 5 mins
# 68%, time left: 261 sec
# 75%, time left: 208 sec
# 81%, time left: 156 sec
# 87%, time left: 104 sec
# 93%, time left: 52 sec
# 0%, time left: unknown
# 6%, time left: 86 sec
# 12%, time left: 76 sec
# 18%, time left: 72 sec
# 25%, time left: 64 sec
# 31%, time left: 59 sec
# 37%, time left: 52 sec
# 43%, time left: 47 sec
# 50%, time left: 40 sec
# 56%, time left: 35 sec
# 62%, time left: 30 sec
# 68%, time left: 24 sec
# 75%, time left: 19 sec
# 81%, time left: 14 sec
# 87%, time left: 9 sec
# 93%, time left: 4 sec
# 0%, time left: unknown
# 6%, time left: 4 sec
# 12%, time left: 3 sec
# 18%, time left: 3 sec
# 25%, time left: 3 sec
# 31%, time left: 3 sec
# 37%, time left: 2 sec
# 43%, time left: 2 sec
# 50%, time left: 2 sec
# 56%, time left: 1 sec
# 62%, time left: 1 sec
# 68%, time left: 1 sec
# 75%, time left: 1 sec
# 81%, time left: 0 sec
# 87%, time left: 0 sec
# 93%, time left: 0 sec
